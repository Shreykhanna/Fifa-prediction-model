# %%
import pandas as pd
from pre_processing_pipeline import pre_processing_pipeline
from win_loss_predictions import win_loss_predicions
from phik_matrix_calculation import phik_matrix_calculation
from train_test_split import _train_test_split

fifa_dataset = pd.read_csv('dataset/fifa_wc_mens_match_dataset_1970_2022.csv', sep=',', na_values=[''], quotechar='"')

dataFrame = win_loss_predicions(fifa_dataset)

filtered_fifa_data= phik_matrix_calculation(dataFrame)

X_train, X_test, y_train, y_test = _train_test_split(filtered_fifa_data)

pre_processing_pipeline(X_train,X_test,y_train,y_test)
# Out:
# C:\Users\khann\PyCharmMiscProject\.venv\Lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable replayed for analysis 1. Dropping this column
#   warnings.warn(
# C:\Users\khann\PyCharmMiscProject\.venv\Lib\site-packages\phik\data_quality.py:72: UserWarning: Not enough unique value for variable replay for analysis 1. Dropping this column
#   warnings.warn(
# Target correlatons
# tournament_name                  0.000000
# country_name                     0.000000
# team_name                        0.407703
# opponent_name                    0.428948
# home_team                        0.090224
# away_team                        0.090224
# goals_for                        0.581716
# goals_against                    0.625116
# extra_time                       0.086365
# penalty_shootout                 0.064153
# penalties_for                    0.302898
# penalties_against                0.294758
# is_host                          0.050210
# ...
